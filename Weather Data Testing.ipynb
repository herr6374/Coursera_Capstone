# %%
# The code was removed by Watson Studio for sharing.
# Out:
#        STATION                      NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 1  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 2  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 3  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 4  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
#
#          DATE   AWND  PGTM  PRCP  SNOW  ...  TMIN  WSF5  WT01  WT02  WT03  \
# 0  2015-01-01  13.87   NaN  0.00   0.0  ...    27  31.1   NaN   NaN   NaN
# 1  2015-01-02  13.65   NaN  0.00   0.0  ...    35  32.0   NaN   NaN   NaN
# 2  2015-01-03   9.62   NaN  0.67   0.0  ...    31  19.9   1.0   NaN   NaN
# 3  2015-01-04  10.96   NaN  0.31   0.0  ...    41  44.1   1.0   1.0   NaN
# 4  2015-01-05  20.80   NaN  0.00   0.0  ...    22  49.0   NaN   NaN   NaN
#
#    WT04  WT05  WT06  WT08  WT09
# 0   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df_data_1.head(20)
# Out:
#         STATION                      NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 1   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 2   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 3   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 4   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 5   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 6   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 7   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 8   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 9   USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 10  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# 11  USW00014732  LAGUARDIA AIRPORT, NY US  40.77944  -73.88035        3.4
# ...

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2085 entries, 0 to 2084
# Data columns (total 23 columns):
# STATION      2085 non-null object
# NAME         2085 non-null object
# LATITUDE     2085 non-null float64
# LONGITUDE    2085 non-null float64
# ELEVATION    2085 non-null float64
# DATE         2085 non-null object
# AWND         2081 non-null float64
# PGTM         1 non-null float64
# PRCP         2085 non-null float64
# SNOW         2084 non-null float64
# SNWD         2085 non-null float64
# TAVG         2080 non-null float64
# TMAX         2085 non-null int64
# TMIN         2085 non-null int64
# WSF5         2077 non-null float64
# WT01         637 non-null float64
# WT02         95 non-null float64
# WT03         166 non-null float64
# WT04         32 non-null float64
# WT05         2 non-null float64
# WT06         25 non-null float64
# WT08         304 non-null float64
# WT09         7 non-null float64
# dtypes: float64(18), int64(2), object(3)
# ...

# %%
df_data_1.drop(columns=['PGTM', 'ELEVATION', 'LATITUDE', 'LONGITUDE', 'WT01', 'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT08', 'WT09'])
# Out:
#           STATION                      NAME        DATE   AWND  PRCP  SNOW  \
# 0     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-01  13.87  0.00   0.0
# 1     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-02  13.65  0.00   0.0
# 2     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-03   9.62  0.67   0.0
# 3     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-04  10.96  0.31   0.0
# 4     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-05  20.80  0.00   0.0
# 5     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-06   8.28  0.05   1.0
# 6     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-07  19.91  0.00   0.0
# 7     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-08  14.32  0.00   0.0
# 8     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-09  16.11  0.12   1.8
# 9     USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-10  14.32  0.00   0.0
# 10    USW00014732  LAGUARDIA AIRPORT, NY US  2015-01-11   8.72  0.00   0.0
# ...

# %%
df_data_1['DATE'] = pd.to_datetime(df_data_1['DATE'])

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2085 entries, 0 to 2084
# Data columns (total 23 columns):
# STATION      2085 non-null object
# NAME         2085 non-null object
# LATITUDE     2085 non-null float64
# LONGITUDE    2085 non-null float64
# ELEVATION    2085 non-null float64
# DATE         2085 non-null datetime64[ns]
# AWND         2081 non-null float64
# PGTM         1 non-null float64
# PRCP         2085 non-null float64
# SNOW         2084 non-null float64
# SNWD         2085 non-null float64
# TAVG         2080 non-null float64
# TMAX         2085 non-null int64
# TMIN         2085 non-null int64
# WSF5         2077 non-null float64
# WT01         637 non-null float64
# WT02         95 non-null float64
# WT03         166 non-null float64
# WT04         32 non-null float64
# WT05         2 non-null float64
# WT06         25 non-null float64
# WT08         304 non-null float64
# WT09         7 non-null float64
# ...

# %%
body = client_d48f5344bf0c4271aeab28f38556b695.get_object(Bucket='courseracapstone-donotdelete-pr-bsz6imthwkwnvj',Key='Motor_Vehicle_Collisions_-_Crashes.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    CRASH DATE CRASH TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/13/2020      13:20  QUEENS    11004   0.000000   0.000000
# 1  09/12/2020      18:23     NaN      NaN        NaN        NaN
# 2  09/12/2020      22:00     NaN      NaN  40.819378 -73.960350
# 3  09/11/2020       0:16   BRONX    10463  40.879555 -73.904335
# 4  09/10/2020      10:26   BRONX    10455  40.818157 -73.906250
#
#                   LOCATION                    ON STREET NAME  \
# 0               (0.0, 0.0)                               NaN
# 1                      NaN  102 CROSS DRIVE
# 2   (40.819378, -73.96035)  HENRY HUDSON PARKWAY
# 3  (40.879555, -73.904335)                               NaN
# 4   (40.818157, -73.90625)  FOREST AVENUE
#
# ...

# %%
df_data_2['CRASH DATE'] = pd.to_datetime(df_data_2['CRASH DATE'])

# %%
pd.merge(left=df_data_1, left_on='DATE',
         right=df_data_2, right_on='CRASH DATE')
# Out:
#              STATION                      NAME  LATITUDE_x  LONGITUDE_x  \
# 0        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 1        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 2        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 3        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 4        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 5        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 6        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 7        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 8        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 9        USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 10       USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# 11       USW00014732  LAGUARDIA AIRPORT, NY US    40.77944    -73.88035
# ...
